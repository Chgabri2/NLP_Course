# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg

# %%
def generateDataset(N, f, sigma):
    vf = np.vectorize(f) 
    mu = 0.0
    x= np.linspace(0,1,N)
    normal=np.random.default_rng().normal(mu, sigma, N)
    t = vf(x) + normal
    return x,t

# %%
def f(x): return math.sin(2 * math.pi * x)

# %%
x,t=generateDataset(100, f, 0.03)
plt.scatter(x,t)

# %%
def E(w):
    return 0.5*np.dot(y(x)-t,y(x)-t)

# %%
def y(x,w,M):
    phi= np.array([[a**i for i in range (M+1)]for a in x])
    return np.dot(phi,w)

# %%
def optimizeLS(x, t, M):
    phi= np.array([[a**i for i in range (M+1)]for a in x])
    prod = np.dot(phi.T, phi)                  
    i = np.linalg.inv(prod)                   
    m = np.dot(i, phi.T)                      
    wLS = np.dot(m, t)  
    return wLS

# %%
vf = np.vectorize(f) 
x,t = generateDataset(10, f, 0.03)
x1=np.linspace(0,1,100)
plt.plot(x1, vf(x1), label="f(x)")
for M in [1,3,5,10]:
    wLS = optimizeLS(x,t,M)
    plt.plot(x, y(x,wLS,M), label=f"M={M}")
    plt.xlabel('x')
    plt.ylabel('y(x)')
leg = plt.legend(loc='best', ncol=2, shadow=True, fancybox=True)
plt.show()

# %%
vf = np.vectorize(f) 
x,t = generateDataset(10, f, 0.03)
x1=np.linspace(0,1,100)
i=1
for M in [1,3,5,10]:
    wLS = optimizeLS(x,t,M)
    plt.figure(i)
    plt.title(f'M={M}')
    plt.plot(x1,vf(x1))
    plt.xlabel('x')
    plt.ylabel('y(x)')
    plt.axhline(y=0, color='k')
    plt.plot(x, y(x,wLS,M),label="m=%m" )
    i=i+1

plt.show()

# %%
def optimizePLS(x, t, M, lamda):
    phi= np.array([[a**i for i in range (M+1)]for a in x])
    prod = np.dot(phi.T, phi)+ lamda*np.eye(M+1)                  
    i = np.linalg.inv(prod) 
    m = np.dot(i, phi.T)                      
    wPLS = np.dot(m, t)  
    return wPLS

# %%
def generateDataset3(N, f, sigma):
    vf = np.vectorize(f) 
    mu = 0.0
    x= np.linspace(0,1,3*N)
    np.random.shuffle(x)
    normal=np.random.default_rng().normal(mu, sigma, 3*N)
    t = vf(x) + normal
    return x[:N],t[:N],x[N:2*N],t[N:2*N],x[2*N:],t[2*N:]

# %%
x1,t1,x2,t2,x3,t3= generateDataset3(10, f, 0.03)
print(x1,'\n','\n',t1,'\n','\n',x2,'\n','\n',t2,'\n','\n',x3,'\n','\n',t3,'\n')
# Out:
# [0.37931034 0.89655172 0.17241379 0.4137931  0.55172414 0.06896552
#  0.31034483 0.86206897 0.68965517 0.79310345]
#
#  [ 0.67511438 -0.6845476   0.87924951  0.50420676 -0.30331792  0.40084094
#   0.92635408 -0.76404315 -0.86578931 -0.97935667]
#
#  [0.82758621 0.24137931 0.         0.48275862 0.10344828 0.72413793
#  0.62068966 0.20689655 0.03448276 1.        ]
#
#  [-0.85978789  1.04052854  0.02155574  0.1442391   0.592827   -0.97128904
#  -0.72490927  0.9450327   0.22041806  0.04693892]
#
#  [0.75862069 0.44827586 0.27586207 0.51724138 0.65517241 0.96551724
#  0.5862069  0.13793103 0.93103448 0.34482759]
#
#  [-1.02637619  0.33930523  0.96194606 -0.13740711 -0.85539935 -0.21616359
#  -0.54832174  0.7346998  -0.39855203  0.85902338]

# %%
plt.scatter(x1,t1)
plt.scatter(x2,t2)
plt.scatter(x3,t3)

# %%
def NEw(x, t, w, N,M):
    err=t-y(x,w,M)
    return (1/N)*(math.sqrt(np.dot(err,err)))

# %% [markdown]
# Given the synthetic dataset, optimize for the value of λ by varying the value of log(λ) from -40 to -20
# on the development set. Draw the plot of the normalized error of the model for the training, development
# and test for the case of N = 10 and the case of N=100. The normalized error of the model is defined as:

# %%
N=10
M=5
xt, tt, xv, tv, xts, tts =generateDataset3(N, f, 0.03)

r=[pow(2,i) for i in range(-40,-19)]
NE_train=[NEw(xt,tt,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
NE_val=[NEw(xv,tv,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
NE_test= [NEw(xts,tts,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
#plt.plot(r,NE_train,label="train")
plt.plot(r,NE_val,label="val")
#plt.plot(r,NE_test,label="test")
plt.xlabel("lambda")
plt.ylabel("normalized error")
plt.title("N=10")
plt.legend(loc='lower right')
plt.show()

# %%
N=100
M=5
xt, tt, xv, tv, xts, tts =generateDataset3(N, f, 0.03)

r=[pow(2,i) for i in range(-40,-19)]
NE_train=[NEw(xt,tt,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
NE_val=[NEw(xv,tv,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
NE_test= [NEw(xts,tts,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
plt.plot(r,NE_val,label="val")
plt.xlabel("lambda")
plt.ylabel("normalized error")
plt.title("N=100")
plt.show()

# %%
xt, tt, xv, tv, xts, tts =generateDataset3(N, f, 0.03)

# %%
def optimizePLS2(xt, tt, xv, tv, M):
    NE=[NEw(xv,tv,optimizePLS(xt, tt, M, lamda),N,M) for lamda in r]
    best= np.argmin(NE_val)-40.
    return pow(2,best)

# %%
optimizePLS2(xt, tt, xv, tv, M)
# Out:
# 2.384185791015625e-07

# %%
N = 10
M = 5
xt, tt, xv, tv, xts, tts =generateDataset3(N, f, 0.03)
lamda=optimizePLS2(xt, tt, xv, tv, M)
wPLS=optimizePLS(xt, tt, M, lamda)
x1=np.linspace(0,1,100)
plt.figure(1)
plt.title('train,N=10')
new_x1, new_y1 = zip(*sorted(zip(xt, tt)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x1, new_y1,label="t" )
plt.legend()


plt.figure(2)
plt.title('validate,N=10')
new_x2, new_y2 = zip(*sorted(zip(xv, tv)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x2, new_y2 ,label="t")
plt.legend()


plt.figure(3)
plt.title('test,N=10')
new_x3, new_y3 = zip(*sorted(zip(xts, tts)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x3, new_y3,label="t" )
plt.legend()

plt.show()

# %%
N = 100
M = 5
xt, tt, xv, tv, xts, tts =generateDataset3(N, f, 0.03)
lamda=optimizePLS2(xt, tt, xv, tv, M)
wPLS=optimizePLS(xt, tt, M, lamda)
x1=np.linspace(0,1,100)
plt.figure(1)
plt.title('train,N=100')
new_x1, new_y1 = zip(*sorted(zip(xt, tt)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x1, new_y1,label="t" )
plt.legend()


plt.figure(2)
plt.title('validate,N=100')
new_x2, new_y2 = zip(*sorted(zip(xv, tv)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x2, new_y2 ,label="t")
plt.legend()


plt.figure(3)
plt.title('test,N=100')
new_x3, new_y3 = zip(*sorted(zip(xts, tts)))
plt.plot(x1,vf(x1),label="f(x)")
plt.plot(new_x3, new_y3,label="t" )
plt.legend()

plt.show()

# %% [markdown]
# something look weird in this plots that change all the time...

# %%
def bayesianEstimator(x, t, M, alpha, sigma2):
    phi= np.array([[a**i for i in range (M+1)]for a in x])  
    S_inv= alpha*np.eye(M+1)+ (1/sigma2**2)*np.dot(phi.T,phi)  
    S=np.linalg.inv(S_inv)
    
    def m(y):
        phi_x=np.array([y**i for i in range(M+1)]).T
        prod= np.dot(phi.T,t) 
        m=(1/sigma2**2)*np.dot(np.dot(phi_x.T,S),prod) 
        return m
    def s(y):
        phi_x=np.array([pow(y,i) for i in range(M+1)]).T  
        s=sigma2**2+np.dot(np.dot(phi_x.T,S),phi_x) 
        return s
    return m,s

# %%
x, t=generateDataset(100, f, 0.03)

# %%
m,s= bayesianEstimator(x, t, 5, 0.1, 0.03)

# %%
m(xt[2])
# Out:
# 0.8490143700122263

# %%
N=10
alpha = 0.005
sigma2 = 1/11.1
M = 9
x1=np.linspace(0,1,100)
x, t=generateDataset(N, f, 0.03)
#figure
fig = plt.gcf()
fig.set_size_inches(11,8)
plt.xlabel("x")
plt.ylabel("t")
plt.title("N=10")
#sin function
plt.plot(x1,vf(x1),label="f(x)")
#mean
m,s= bayesianEstimator(x, t, M, alpha, sigma2)
vm = np.vectorize(m) 
vs = np.vectorize(s)
sqrt_= np.vectorize(math.sqrt)
plt.plot(x,vm(x),color='g',label="mean")
#points
plt.scatter(x,t,facecolors='none',edgecolors='b',marker='o',label="t")
# confidence interval
plt.fill_between(x, (vm(x) - np.sqrt(vs(x))), (vm(x) + np.sqrt(vs(x))), color='r', alpha=.1)
plt.legend()
plt.show()

# %%
N=100
alpha = 0.005
sigma2 = 1/11.1
M = 9
x1=np.linspace(0,1,100)
x, t=generateDataset(N, f, 0.03)
#figure
fig = plt.gcf()
fig.set_size_inches(11,8)
plt.xlabel("x")
plt.ylabel("t")
plt.title("N=100")
#sin function
plt.plot(x1,vf(x1),color='r',label="f(x)")
#mean
m,s= bayesianEstimator(x, t, M, alpha, sigma2)
vm = np.vectorize(m) 
vs = np.vectorize(s)
sqrt_= np.vectorize(math.sqrt)
plt.plot(x,vm(x),color='g',label="mean")
#points
plt.scatter(x,t,color='b',facecolors='none',edgecolors='b',marker='.',label="t")
# confidence interval
plt.fill_between(x, (vm(x) - np.sqrt(vs(x))), (vm(x) + np.sqrt(vs(x))), color='r', alpha=.1)
plt.legend()
plt.show()

# %% [markdown]
# Interpret the height of the band around the most likely function in terms of the distribution of the xs in your synthetic dataset.
# Can you think of ways to make this height very small in one segment of the function and large in another?
