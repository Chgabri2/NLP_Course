# %%
# %run functions.ipynb

# %%
import codecs
import math
import random
import string
import time
import numpy as np
import torch
from sklearn.metrics import accuracy_score

'''
Don't change these constants for the classification task.
You may use different copies for the sentence generation model.
'''
languages = ["af", "cn", "de", "fi", "fr", "in", "ir", "pk", "za"]
all_letters = string.ascii_letters + " .,;'"
n_letters = len(all_letters)


import unicodedata

# Turn a Unicode string to plain ASCII, thanks to https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

# print(unicodeToAscii('Ślusàrski'))

# Build the category_lines dictionary, a list of names per language
category_lines = {}
all_categories = []
category_lines_test = {}
all_categories_test = []
# Read a file and split into lines
def readLines(filename):
    lines = codecs.open(filename, "r",encoding='utf-8', errors='ignore').read().strip().split('\n')
    return [unicodeToAscii(line) for line in lines]

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob
import os

def findFiles(path): return glob.glob(path)

print(findFiles('data/cities/train/*.txt'))


for filename in findFiles('data/cities/train/*.txt'):
    category = os.path.splitext(os.path.basename(filename))[0]
    all_categories.append(category)
    lines = readLines(filename)
    category_lines[category] = lines
n_categories= len(all_categories)
# Out:
# ['data/cities/train/in.txt', 'data/cities/train/pk.txt', 'data/cities/train/fr.txt', 'data/cities/train/af.txt', 'data/cities/train/cn.txt', 'data/cities/train/za.txt', 'data/cities/train/fi.txt', 'data/cities/train/ir.txt', 'data/cities/train/de.txt']

# %%
for filename in findFiles('data/cities/val/*.txt'):
    category = os.path.splitext(os.path.basename(filename))[0]
    all_categories_test.append(category)
    lines = readLines(filename)
    category_lines_test[category] = lines
n_categories_test= len(all_categories_test)

# %%
#train on rnn
n_hidden = 128
rnn = RNN(n_letters, n_hidden, n_categories)
train_model(all_categories,category_lines,rnn,learning_rate=0.001)
# Out:
# 5000 5% (0m 10s) 2.0932 bhanga / in ✓
# 10000 10% (0m 20s) 2.2059 kulader / de ✗ (pk)
# 15000 15% (0m 31s) 1.8957 gundah / af ✓
# 20000 20% (0m 41s) 2.1670 grodek folwark / fi ✗ (de)
# 25000 25% (0m 51s) 1.9599 ban chin kong / cn ✗ (in)
# 30000 30% (1m 1s) 1.8906 khwaja zayed / pk ✗ (za)
# 35000 35% (1m 12s) 2.0966 gillouin / in ✗ (fr)
# 40000 40% (1m 22s) 2.0429 duolun / de ✗ (cn)
# 45000 45% (1m 33s) 0.7741 poliwuching / cn ✓
# 50000 50% (1m 44s) 1.6448 haouayej serhir / za ✗ (ir)
# 55000 55% (1m 54s) 1.3939 mian ali faqiran / af ✗ (pk)
# 60000 60% (2m 5s) 2.7467 chandzu / cn ✗ (ir)
# 65000 65% (2m 15s) 0.7024 sitio wanderlei figueira / fi ✓
# 70000 70% (2m 25s) 0.7015 rickertsreute / de ✓
# 75000 75% (2m 35s) 1.6814 inahasa / pk ✗ (in)
# 80000 80% (2m 45s) 3.0931 musa ronial ziarat / za ✗ (pk)
# 85000 85% (2m 56s) 1.8755 waschow / cn ✗ (de)
# 90000 90% (3m 6s) 3.7050 kafr al jara'idah / af ✗ (fr)
# 95000 95% (3m 15s) 0.2080 gaillardboiscressenville / fr ✓
# 100000 100% (3m 25s) 0.7478 goth mahbub raheja / pk ✓

# %%
#evaluate model on the training set
evaluate_model(all_categories,category_lines,rnn)
# Out:
# confusion= tensor([[0.3665, 0.0909, 0.1278, 0.0303, 0.1799, 0.0436, 0.0729, 0.0540, 0.0341],
#         [0.0531, 0.5476, 0.0189, 0.1551, 0.0480, 0.0420, 0.0437, 0.0506, 0.0411],
#         [0.0730, 0.0098, 0.5934, 0.0738, 0.0383, 0.0267, 0.0872, 0.0347, 0.0632],
#         [0.0225, 0.1695, 0.0135, 0.4545, 0.0577, 0.0667, 0.1163, 0.0460, 0.0532],
#         [0.0710, 0.0109, 0.0200, 0.0255, 0.7671, 0.0564, 0.0282, 0.0064, 0.0146],
#         [0.0206, 0.0358, 0.0716, 0.0680, 0.0295, 0.6741, 0.0242, 0.0161, 0.0600],
#         [0.0520, 0.0512, 0.0711, 0.1180, 0.0208, 0.0069, 0.6184, 0.0321, 0.0295],
#         [0.1229, 0.1682, 0.0684, 0.2274, 0.0388, 0.0693, 0.0786, 0.1534, 0.0730],
#         [0.0704, 0.0467, 0.1940, 0.0595, 0.0677, 0.0366, 0.0274, 0.0302, 0.4675]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.37      0.39      1056
#          1.0       0.50      0.55      0.52      1167
#          2.0       0.51      0.59      0.55      1124
#          3.0       0.37      0.45      0.41      1109
#          4.0       0.62      0.77      0.68      1099
#          5.0       0.66      0.67      0.67      1117
#          6.0       0.57      0.62      0.60      1153
#          7.0       0.36      0.15      0.21      1082
#          8.0       0.55      0.47      0.51      1093
#
#     accuracy                           0.52     10000
#    macro avg       0.51      0.52      0.50     10000
# weighted avg       0.51      0.52      0.51     10000

# %%
#evaluate model on the validation set
evaluate_model(all_categories_test,category_lines_test,rnn,500)
# Out:
# confusion= tensor([[0.2727, 0.1091, 0.0545, 0.0364, 0.3091, 0.0364, 0.0182, 0.1091, 0.0545],
#         [0.0784, 0.4706, 0.0196, 0.2549, 0.0588, 0.0196, 0.0784, 0.0000, 0.0196],
#         [0.1207, 0.0172, 0.4483, 0.0345, 0.0690, 0.0690, 0.0690, 0.0345, 0.1379],
#         [0.0179, 0.1786, 0.0714, 0.3929, 0.0536, 0.0714, 0.1429, 0.0179, 0.0536],
#         [0.0698, 0.0000, 0.0465, 0.0000, 0.7907, 0.0465, 0.0465, 0.0000, 0.0000],
#         [0.0339, 0.0169, 0.0847, 0.0339, 0.0508, 0.6102, 0.1356, 0.0000, 0.0339],
#         [0.0508, 0.0169, 0.1017, 0.1186, 0.0000, 0.0339, 0.6780, 0.0000, 0.0000],
#         [0.1029, 0.2647, 0.0000, 0.2941, 0.0147, 0.0294, 0.1618, 0.0735, 0.0588],
#         [0.0588, 0.0000, 0.2353, 0.0000, 0.0588, 0.0980, 0.0196, 0.0784, 0.4510]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.27      0.30        55
#          1.0       0.39      0.47      0.43        51
#          2.0       0.44      0.45      0.44        58
#          3.0       0.32      0.39      0.35        56
#          4.0       0.50      0.79      0.61        43
#          5.0       0.62      0.61      0.62        59
#          6.0       0.51      0.68      0.58        59
#          7.0       0.28      0.07      0.12        68
#          8.0       0.52      0.45      0.48        51
#
#     accuracy                           0.45       500
#    macro avg       0.44      0.47      0.44       500
# weighted avg       0.43      0.45      0.43       500

# %%
#train on rnn_dropout
n_hidden = 128
rnn_dropout = RNN_dropout(n_letters, n_hidden, n_categories)
train_model(all_categories,category_lines,rnn_dropout,learning_rate=0.001)
# Out:
# 5000 5% (0m 14s) 2.1401 kofia / za ✗ (fi)
# 10000 10% (0m 29s) 1.9916 fives / fi ✓
# 15000 15% (0m 45s) 2.3169 krakinov / fi ✗ (in)
# 20000 20% (1m 0s) 2.1117 chenjiatai / fr ✗ (cn)
# 25000 25% (1m 15s) 2.1250 lesozayodsk / fi ✗ (za)
# 30000 30% (1m 30s) 2.2527 kobzarovka / fr ✗ (za)
# 35000 35% (1m 44s) 2.1099 laakamaki / fi ✓
# 40000 40% (1m 59s) 2.0807 fila alta / fr ✗ (fi)
# 45000 45% (2m 16s) 2.1587 banu kheyl / za ✗ (af)
# 50000 50% (2m 30s) 2.2073 alfabad / za ✗ (ir)
# 55000 55% (2m 46s) 2.1283 fisher manor / za ✗ (fi)
# 60000 60% (3m 1s) 2.1311 ryukhyalya / cn ✗ (fi)
# 65000 65% (3m 15s) 2.2000 tirkha chin / za ✗ (ir)
# 70000 70% (3m 30s) 2.1666 vincent / cn ✗ (fr)
# 75000 75% (3m 45s) 2.1725 zavinine / fi ✗ (za)
# 80000 80% (3m 58s) 2.2271 kampong mempuing / cn ✗ (in)
# 85000 85% (4m 12s) 2.0468 baizhuya / cn ✓
# 90000 90% (4m 26s) 2.2275 deh hud / fi ✗ (ir)
# 95000 95% (4m 41s) 2.2557 askine payan / fi ✗ (af)
# 100000 100% (4m 55s) 2.1442 wuhohsien / za ✗ (cn)

# %%
#evaluate model on the training set
evaluate_model(all_categories,category_lines,rnn_dropout)
# Out:
# confusion= tensor([[0.0000, 0.0000, 0.2536, 0.0018, 0.2977, 0.1475, 0.2797, 0.0180, 0.0018],
#         [0.0000, 0.0000, 0.2705, 0.0071, 0.3238, 0.1423, 0.1931, 0.0623, 0.0009],
#         [0.0009, 0.0000, 0.1843, 0.0043, 0.1539, 0.2478, 0.3948, 0.0096, 0.0043],
#         [0.0009, 0.0000, 0.2168, 0.0111, 0.3625, 0.1531, 0.2168, 0.0341, 0.0046],
#         [0.0000, 0.0009, 0.2211, 0.0009, 0.3584, 0.1336, 0.2775, 0.0056, 0.0019],
#         [0.0000, 0.0019, 0.1918, 0.0028, 0.3315, 0.1592, 0.2765, 0.0354, 0.0009],
#         [0.0000, 0.0034, 0.2661, 0.0017, 0.2885, 0.1456, 0.2687, 0.0215, 0.0043],
#         [0.0000, 0.0009, 0.2972, 0.0000, 0.2570, 0.1645, 0.2411, 0.0346, 0.0047],
#         [0.0000, 0.0009, 0.2203, 0.0034, 0.2091, 0.2005, 0.3365, 0.0232, 0.0060]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00      1112
#          1.0       0.00      0.00      0.00      1124
#          2.0       0.09      0.18      0.12      1150
#          3.0       0.32      0.01      0.02      1084
#          4.0       0.13      0.36      0.19      1063
#          5.0       0.10      0.16      0.12      1074
#          6.0       0.11      0.27      0.16      1161
#          7.0       0.14      0.03      0.06      1070
#          8.0       0.21      0.01      0.01      1162
#
#     accuracy                           0.11     10000
#    macro avg       0.12      0.11      0.08     10000
# weighted avg       0.12      0.11      0.08     10000

# %%
#evaluate model on the validation set
evaluate_model(all_categories_test,category_lines_test,rnn_dropout,500)
# Out:
# confusion= tensor([[0.0000, 0.0000, 0.1695, 0.0169, 0.3898, 0.1186, 0.2712, 0.0339, 0.0000],
#         [0.0000, 0.0000, 0.2667, 0.0000, 0.3667, 0.1000, 0.2333, 0.0333, 0.0000],
#         [0.0000, 0.0000, 0.1552, 0.0000, 0.1379, 0.2759, 0.4138, 0.0172, 0.0000],
#         [0.0000, 0.0000, 0.4746, 0.0000, 0.1864, 0.1525, 0.1525, 0.0169, 0.0169],
#         [0.0000, 0.0000, 0.1765, 0.0000, 0.3529, 0.1373, 0.2941, 0.0392, 0.0000],
#         [0.0000, 0.0000, 0.2115, 0.0000, 0.3077, 0.0577, 0.3077, 0.0769, 0.0385],
#         [0.0000, 0.0000, 0.2963, 0.0370, 0.1852, 0.1296, 0.3333, 0.0185, 0.0000],
#         [0.0000, 0.0000, 0.3051, 0.0169, 0.2881, 0.1017, 0.2203, 0.0508, 0.0169],
#         [0.0000, 0.0000, 0.3333, 0.0208, 0.1250, 0.2083, 0.2917, 0.0208, 0.0000]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        59
#          1.0       0.00      0.00      0.00        60
#          2.0       0.07      0.16      0.09        58
#          3.0       0.00      0.00      0.00        59
#          4.0       0.14      0.35      0.20        51
#          5.0       0.04      0.06      0.05        52
#          6.0       0.13      0.33      0.19        54
#          7.0       0.18      0.05      0.08        59
#          8.0       0.00      0.00      0.00        48
#
#     accuracy                           0.10       500
#    macro avg       0.06      0.11      0.07       500
# weighted avg       0.06      0.10      0.07       500
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#train on rnn_noZeroInit
n_hidden = 128
rnn_noZeroInit = RNN_noZeroInit(n_letters, n_hidden, n_categories)
train_model(all_categories,category_lines,rnn_noZeroInit,learning_rate=0.001)
# Out:
# 5000 5% (0m 10s) 2.3114 francovce / ir ✗ (fr)
# 10000 10% (0m 21s) 2.1839 burashk / in ✗ (ir)
# 15000 15% (0m 31s) 2.2009 dahanae ghori / ir ✗ (af)
# 20000 20% (0m 42s) 2.1712 nizhniy zaramag / de ✗ (za)
# 25000 25% (0m 52s) 2.1700 afatyakasi / ir ✗ (af)
# 30000 30% (1m 2s) 2.2052 yangjiang linchang / za ✗ (in)
# 35000 35% (1m 12s) 2.1238 rofingen / af ✗ (fi)
# 40000 40% (1m 22s) 2.2053 zfizef / ir ✗ (fi)
# 45000 45% (1m 34s) 2.1384 dahane khar bayd / za ✗ (af)
# 50000 50% (1m 44s) 2.2394 chuancun / af ✗ (cn)
# 55000 55% (1m 57s) 2.3226 le blizon / fi ✗ (fr)
# 60000 60% (2m 9s) 2.1458 razaza / in ✗ (za)
# 65000 65% (2m 26s) 2.3178 liguangshan / af ✗ (cn)
# 70000 70% (2m 39s) 2.3353 lalheue / ir ✗ (fr)
# 75000 75% (2m 50s) 2.3118 guantian / af ✗ (cn)
# 80000 80% (3m 0s) 2.2384 shishugou / af ✗ (cn)
# 85000 85% (3m 10s) 2.1739 qadir khel / in ✗ (af)
# 90000 90% (3m 21s) 2.2687 haut chaserey / af ✗ (fr)
# 95000 95% (3m 31s) 2.1679 lazagurria / in ✗ (za)
# 100000 100% (3m 42s) 2.0787 cot girer / ir ✓

# %%
#evaluate model on the training set
evaluate_model(all_categories,category_lines,rnn_noZeroInit)
# Out:
# confusion= tensor([[0.2097, 0.0009, 0.0000, 0.3867, 0.0000, 0.1186, 0.0319, 0.2460, 0.0062],
#         [0.2765, 0.0028, 0.0000, 0.2268, 0.0009, 0.0431, 0.0244, 0.4217, 0.0037],
#         [0.1110, 0.0000, 0.0087, 0.4258, 0.0000, 0.0564, 0.0520, 0.3400, 0.0061],
#         [0.2950, 0.0000, 0.0009, 0.2839, 0.0000, 0.0538, 0.0241, 0.3330, 0.0093],
#         [0.0776, 0.0000, 0.0000, 0.4769, 0.0000, 0.2049, 0.0253, 0.1979, 0.0174],
#         [0.3237, 0.0000, 0.0000, 0.2236, 0.0000, 0.0613, 0.0198, 0.3616, 0.0099],
#         [0.3279, 0.0000, 0.0000, 0.2650, 0.0018, 0.0692, 0.0126, 0.3172, 0.0063],
#         [0.2270, 0.0018, 0.0000, 0.2518, 0.0009, 0.0771, 0.0195, 0.4113, 0.0106],
#         [0.2047, 0.0000, 0.0000, 0.3386, 0.0019, 0.1284, 0.0186, 0.3042, 0.0037]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.10      0.21      0.14      1130
#          1.0       0.50      0.00      0.01      1067
#          2.0       0.91      0.01      0.02      1153
#          3.0       0.10      0.28      0.14      1078
#          4.0       0.00      0.00      0.00      1147
#          5.0       0.07      0.06      0.07      1109
#          6.0       0.05      0.01      0.02      1113
#          7.0       0.14      0.41      0.21      1128
#          8.0       0.05      0.00      0.01      1075
#
#     accuracy                           0.11     10000
#    macro avg       0.21      0.11      0.07     10000
# weighted avg       0.22      0.11      0.07     10000

# %%
#evaluate model on the validation set
evaluate_model(all_categories_test,category_lines_test,rnn_noZeroInit,500)
# Out:
# confusion= tensor([[0.3750, 0.0000, 0.0000, 0.2812, 0.0000, 0.1250, 0.0000, 0.2188, 0.0000],
#         [0.3636, 0.0000, 0.0000, 0.1136, 0.0000, 0.0000, 0.0000, 0.5227, 0.0000],
#         [0.0517, 0.0000, 0.0345, 0.4828, 0.0000, 0.0345, 0.0690, 0.3276, 0.0000],
#         [0.2909, 0.0182, 0.0000, 0.2364, 0.0000, 0.0182, 0.0000, 0.4182, 0.0182],
#         [0.0698, 0.0000, 0.0000, 0.5116, 0.0000, 0.0233, 0.0233, 0.3721, 0.0000],
#         [0.2333, 0.0000, 0.0000, 0.2833, 0.0000, 0.0833, 0.0667, 0.3333, 0.0000],
#         [0.4000, 0.0000, 0.0000, 0.3000, 0.0000, 0.0167, 0.0000, 0.2833, 0.0000],
#         [0.3962, 0.0000, 0.0000, 0.1887, 0.0000, 0.0943, 0.0755, 0.2453, 0.0000],
#         [0.2540, 0.0000, 0.0000, 0.3968, 0.0000, 0.1270, 0.0000, 0.2222, 0.0000]])
# classtification report:
#               precision    recall  f1-score   support
#
#          0.0       0.18      0.38      0.24        64
#          1.0       0.00      0.00      0.00        44
#          2.0       1.00      0.03      0.07        58
#          3.0       0.08      0.24      0.12        55
#          4.0       0.00      0.00      0.00        43
#          5.0       0.16      0.08      0.11        60
#          6.0       0.00      0.00      0.00        60
#          7.0       0.08      0.25      0.12        53
#          8.0       0.00      0.00      0.00        63
#
#     accuracy                           0.11       500
#    macro avg       0.17      0.11      0.07       500
# weighted avg       0.18      0.11      0.08       500
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#train on rnn
n_hidden = 128
rnn2 = RNN(n_letters, n_hidden, n_categories)
train_model(all_categories,category_lines,rnn2,learning_rate=0.001)
# Out:
# 5000 5% (0m 10s) 2.2042 bindoumessang / za ✗ (in)

# %%
#train on rnn
n_hidden = 128
rnn2 = RNN(n_letters, n_hidden, n_categories)
train_model(all_categories,category_lines,rnn2,learning_rate=0.005)
